# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %%
# Load data
file_path = r"C:\Users\AmnaSaied\Downloads\Pay prediction dataset2.csv"

# Load the data
df = pd.read_csv(file_path)

# Overview of the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   APA Tenant                      1055 non-null   object
#  1   HasPay                          1055 non-null   int64
#  2   Segment                         1055 non-null   object
#  3   Industry                        1055 non-null   object
#  4   Sub Industry                    1055 non-null   object
#  5   ERP                             1054 non-null   object
#  6   Medius Territory                1055 non-null   object
#  7   Sum of Employees                1029 non-null   float64
#  8   Capture License Type            1055 non-null   object
#  9   Sum of APA License utilization  988 non-null    float64
#  10  AP Automation                   1055 non-null   bool
#  11  Sum of ACV (USD)                1055 non-null   float64
# ...

# %%
print(df.describe())
# Out:
#             HasPay  Sum of Employees  Sum of APA License utilization  \
# count  1055.000000       1029.000000                      988.000000
# mean      0.067299       3413.129252                       65.359312
# std       0.250657      21166.722568                       56.169319
# min       0.000000          3.000000                        0.000000
# 25%       0.000000         76.000000                       47.000000
# 50%       0.000000        288.000000                       67.000000
# 75%       0.000000        900.000000                       82.000000
# max       1.000000     396422.000000                     1544.000000
#
#        Sum of ACV (USD)  Sum of Number of Locations  ActivatedModules  \
# count      1.055000e+03                  964.000000       1055.000000
# mean       6.068700e+04                    4.050830          8.091943
# std        1.131259e+05                    7.786915          1.964602
# ...

# %%
# Check missing values
print(df.isnull().sum())
# Out:
# APA Tenant                         0
# HasPay                             0
# Segment                            0
# Industry                           0
# Sub Industry                       0
# ERP                                1
# Medius Territory                   0
# Sum of Employees                  26
# Capture License Type               0
# Sum of APA License utilization    67
# AP Automation                      0
# Sum of ACV (USD)                   0
# Sum of Number of Locations        91
# ActivatedModules                   0
# ActiveSubsidiaries                 0
# ActiveUsers                        0
# AvgCommentsPerDocument            34
# AvgCompletedTasksPerWeek          27
# AvgInvoicesPerMonth               33
# AvgLinesPerInvoice                27
# AvgOverdueDays                    37
# DistinctLanguages                  0
# AvgTimeToCompleteTask             33
# TotalArchivedInvoices              0
# OverdueInvoiceCount                0
# ...

# %%
# Filter APA tenants with RootCompanyCreatedTimestamp after 01/01/2022
df_filtered = df[df['RootCompanyCreatedTimestamp'] >= '2022-01-01']

# %%
df_filtered.info()
print(df_filtered['HasPay'].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 585 entries, 1 to 1053
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   APA Tenant                      585 non-null    object
#  1   HasPay                          585 non-null    int64
#  2   Segment                         585 non-null    object
#  3   Industry                        585 non-null    object
#  4   Sub Industry                    585 non-null    object
#  5   ERP                             584 non-null    object
#  6   Medius Territory                585 non-null    object
#  7   Sum of Employees                572 non-null    float64
#  8   Capture License Type            585 non-null    object
#  9   Sum of APA License utilization  549 non-null    float64
#  10  AP Automation                   585 non-null    bool
#  11  Sum of ACV (USD)                585 non-null    float64
# ...
